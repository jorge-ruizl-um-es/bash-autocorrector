# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Examen final de prácticas - Fundamentos de Computadores
#
# *Grado en Ciencia e Ingeniería de Datos - Facultad de Informática - Universidad de Murcia*

# %% [markdown]
# |Bloque|Preguntas|	Puntos/preg	| Puntos| Prácticas |
# |------|---------|--------------|-------|----------|
# |1     |	@@B1PREG@@       |	0,25  |	@@B1PUNT@@	|P1,P5|
# |2     |	@@B2PREG@@       |	0,25  |	@@B2PUNT@@	|P1,P5|
# |3     |	@@B3PREG@@       |	0,25  |	@@B3PUNT@@	|P7|
# |4     |	@@B4PREG@@       |	0,25  |	@@B4PUNT@@	|P2|
# |5     |	@@B5PREG@@       |	0,25  |	@@B5PUNT@@	|P4|
# |      |	                 |	      |10	|  |

# %% [markdown]
# [Bloque 1: Consulta y manipulación del sistema de ficheros](./examen-fc-bloque1.ipynb)
#
# [Bloque 2: Búsquedas](./examen-fc-bloque2.ipynb)
#
# [Bloque 3: Gestión de procesos. Redireccionamiento. Tuberías](./examen-fc-bloque3.ipynb)
#
# [Bloque 4: Control de versiones con Git](./examen-fc-bloque4.ipynb)
#
# [Bloque 5: Lenguajes del computador](./examen-fc-bloque5.ipynb)
